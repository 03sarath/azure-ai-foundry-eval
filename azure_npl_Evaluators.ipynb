# %% [markdown]
# # Evaluate with quantitative NLP evaluators
#
# ## Objective
# This notebook demonstrates how to use NLP-based evaluators to assess the quality of generated text by comparing it to reference text. By the end of this tutorial, you'll be able to:
#  - Understand different NLP evaluators such as `BleuScoreEvaluator`, `GleuScoreEvaluator`, `MeteorScoreEvaluator`, and `RougeScoreEvaluator`.
#  - Evaluate dataset using these evaluators.
#
# ## Time
# You should expect to spend about 10 minutes running this notebook.
#
# ## Before you begin
#
# ### Installation
# Install the following packages required to execute this notebook.

# %%
# Install the packages
# %pip install azure-ai-evaluation
# Out:
# Requirement already satisfied: azure-ai-evaluation in ./.venv/lib/python3.12/site-packages (1.10.0)
# Requirement already satisfied: pyjwt>=2.8.0 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (2.10.1)
# Requirement already satisfied: azure-identity>=1.16.0 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (1.25.0)
# Requirement already satisfied: azure-core>=1.30.2 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (1.35.1)
# Requirement already satisfied: nltk>=3.9.1 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (3.9.1)
# Requirement already satisfied: azure-storage-blob>=12.10.0 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (12.26.0)
# Requirement already satisfied: httpx>=0.25.1 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (0.28.1)
# Requirement already satisfied: pandas<3.0.0,>=2.1.2 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (2.3.1)
# Requirement already satisfied: openai>=1.78.0 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (1.99.9)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (0.18.14)
# Requirement already satisfied: msrest>=0.6.21 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (0.7.1)
# Requirement already satisfied: Jinja2>=3.1.6 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (3.1.6)
# Requirement already satisfied: aiohttp>=3.0 in ./.venv/lib/python3.12/site-packages (from azure-ai-evaluation) (3.12.15)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2025.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in ./.venv/lib/python3.12/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->azure-ai-evaluation) (0.2.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.20.1)
# Requirement already satisfied: idna>=2.0 in ./.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.0->azure-ai-evaluation) (3.10)
# Requirement already satisfied: typing-extensions>=4.2 in ./.venv/lib/python3.12/site-packages (from aiosignal>=1.4.0->aiohttp>=3.0->azure-ai-evaluation) (4.14.1)
# Requirement already satisfied: requests>=2.21.0 in ./.venv/lib/python3.12/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in ./.venv/lib/python3.12/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (1.17.0)
# Requirement already satisfied: cryptography>=2.5 in ./.venv/lib/python3.12/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (45.0.6)
# Requirement already satisfied: msal>=1.30.0 in ./.venv/lib/python3.12/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.33.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in ./.venv/lib/python3.12/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: isodate>=0.6.1 in ./.venv/lib/python3.12/site-packages (from azure-storage-blob>=12.10.0->azure-ai-evaluation) (0.7.2)
# Requirement already satisfied: cffi>=1.14 in ./.venv/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (1.17.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (2.22)
# Requirement already satisfied: anyio in ./.venv/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (4.10.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.1->azure-ai-evaluation) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from Jinja2>=3.1.6->azure-ai-evaluation) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (2.5.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in ./.venv/lib/python3.12/site-packages (from msrest>=0.6.21->azure-ai-evaluation) (2.0.0)
# Requirement already satisfied: click in ./.venv/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (8.2.1)
# Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (2025.7.34)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (4.67.1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.78.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.78.0->azure-ai-evaluation) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.78.0->azure-ai-evaluation) (2.11.7)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.12/site-packages (from openai>=1.78.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.78.0->azure-ai-evaluation) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.78.0->azure-ai-evaluation) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.78.0->azure-ai-evaluation) (0.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-evaluation) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
azure_ai_project = {
    "subscription_id": "1c2fd79b-ad21-4ad0-8d53-12de16650452",
    "resource_group_name": "rg-sarath-8734",
    "project_name": "sarath-8734-resource",
}

# %% [markdown]
# ## NLP Evaluators

# %% [markdown]
# ### BleuScoreEvaluator
#
# BLEU (Bilingual Evaluation Understudy) score is commonly used in natural language processing (NLP) and machine
# translation. It is widely used in text summarization and text generation use cases. It evaluates how closely the
# generated text matches the reference text. The BLEU score ranges from 0 to 1, with higher scores indicating
# better quality.

# %%
from azure.ai.evaluation import BleuScoreEvaluator

bleu = BleuScoreEvaluator()

# %%
result = bleu(response="Tokyo is the capital of Japan.", ground_truth="The capital of Japan is Tokyo.")

print(result)
# Out:
# {'bleu_score': 0.22961813530951883, 'bleu_result': 'fail', 'bleu_threshold': 0.5}

# %% [markdown]
# ### GleuScoreEvaluator
#
# The GLEU (Google-BLEU) score evaluator measures the similarity between generated and reference texts by
# evaluating n-gram overlap, considering both precision and recall. This balanced evaluation, designed for
# sentence-level assessment, makes it ideal for detailed analysis of translation quality. GLEU is well-suited for
# use cases such as machine translation, text summarization, and text generation.

# %%
from azure.ai.evaluation import GleuScoreEvaluator

gleu = GleuScoreEvaluator()

# %%
result = gleu(response="Tokyo is the capital of Japan.", ground_truth="The capital of Japan is Tokyo.")

print(result)
# Out:
# {'gleu_score': 0.4090909090909091, 'gleu_result': 'fail', 'gleu_threshold': 0.5}

# %% [markdown]
# ### MeteorScoreEvaluator
#
# The METEOR (Metric for Evaluation of Translation with Explicit Ordering) score grader evaluates generated text by
# comparing it to reference texts, focusing on precision, recall, and content alignment. It addresses limitations of
# other metrics like BLEU by considering synonyms, stemming, and paraphrasing. METEOR score considers synonyms and
# word stems to more accurately capture meaning and language variations. In addition to machine translation and
# text summarization, paraphrase detection is an optimal use case for the METEOR score.

# %%
from azure.ai.evaluation import MeteorScoreEvaluator

meteor = MeteorScoreEvaluator(alpha=0.9, beta=3.0, gamma=0.5)

# %%
result = meteor(response="Tokyo is the capital of Japan.", ground_truth="The capital of Japan is Tokyo.")

print(result)
# Out:
# {'meteor_score': 0.9067055393586005, 'meteor_result': 'pass', 'meteor_threshold': 0.5}

# %% [markdown]
# ### RougeScoreEvaluator
#
# ROUGE (Recall-Oriented Understudy for Gisting Evaluation) is a set of metrics used to evaluate automatic
# summarization and machine translation. It measures the overlap between generated text and reference summaries.
# ROUGE focuses on recall-oriented measures to assess how well the generated text covers the reference text. Text
# summarization and document comparison are among optimal use cases for ROUGE, particularly in scenarios where text
# coherence and relevance are critical.

# %%
from azure.ai.evaluation import RougeScoreEvaluator, RougeType

rouge = RougeScoreEvaluator(rouge_type=RougeType.ROUGE_1)

# %%
result = rouge(response="Tokyo is the capital of Japan.", ground_truth="The capital of Japan is Tokyo.")

print(result)
# Out:
# {'rouge_precision': 1.0, 'rouge_recall': 1.0, 'rouge_f1_score': 1.0, 'rouge_precision_result': 'pass', 'rouge_recall_result': 'pass', 'rouge_f1_score_result': 'pass', 'rouge_precision_threshold': 0.5, 'rouge_recall_threshold': 0.5, 'rouge_f1_score_threshold': 0.5}

# %% [markdown]
# ## Evaluate a Dataset using Math Evaluators
#
# The code below uses the Evaluate API with BLEU, GLEU, METEOR, and ROUGE evaluators to evaluate the results on a dataset.

# %%
from azure.ai.evaluation import evaluate

result = evaluate(
    data="data.jsonl",
    evaluators={
        "bleu": bleu,
        "gleu": gleu,
        "meteor": meteor,
        "rouge": rouge,
    },
)

print (result)
# Out:
# 2025-09-25 14:05:52 +0000 132512976262848 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-09-25 14:05:52 +0000 132512976262848 execution.bulk     INFO     Average execution time for completed lines: 0.0 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-09-25 14:05:52 +0000 132513006683840 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-09-25 14:05:52 +0000 132513006683840 execution.bulk     INFO     Average execution time for completed lines: 0.01 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-09-25 14:05:52 +0000 132512993048256 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-09-25 14:05:52 +0000 132512993048256 execution.bulk     INFO     Average execution time for completed lines: 0.02 seconds. Estimated time for incomplete lines: 0.0 seconds.
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# ======= Run Summary =======
#
# Run name: "gleu_20250925_140552_855030"
# Run status: "Completed"
# Start time: "2025-09-25 14:05:52.855030+00:00"
# Duration: "0:00:01.042658"
#
# ======= Run Summary =======
#
# Run name: "bleu_20250925_140552_848446"
# Run status: "Completed"
# Start time: "2025-09-25 14:05:52.848446+00:00"
# Duration: "0:00:01.049403"
#
# ======= Run Summary =======
#
# Run name: "rouge_20250925_140552_860505"
# Run status: "Completed"
# Start time: "2025-09-25 14:05:52.860505+00:00"
# Duration: "0:00:01.043051"
#
# 2025-09-25 14:05:55 +0000 132512984655552 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-09-25 14:05:55 +0000 132512984655552 execution.bulk     INFO     Average execution time for completed lines: 0.96 seconds. Estimated time for incomplete lines: 0.0 seconds.
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# ======= Run Summary =======
#
# Run name: "meteor_20250925_140552_857537"
# Run status: "Completed"
# Start time: "2025-09-25 14:05:52.857537+00:00"
# Duration: "0:00:02.878164"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "bleu": {
#         "status": "Completed",
#         "duration": "0:00:01.049403",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": null
#     },
#     "gleu": {
#         "status": "Completed",
#         "duration": "0:00:01.042658",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": null
#     },
#     "meteor": {
#         "status": "Completed",
#         "duration": "0:00:02.878164",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": null
#     },
#     "rouge": {
#         "status": "Completed",
#         "duration": "0:00:01.043051",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": null
#     }
# }
#
# ====================================================
#
# {'rows': [{'inputs.response': 'The cat sits on the mat.', 'inputs.ground_truth': 'A cat is sitting on the mat.', 'outputs.bleu.bleu_score': 0.3768499164492419, 'outputs.bleu.bleu_result': 'fail', 'outputs.bleu.bleu_threshold': 0.5, 'outputs.gleu.gleu_score': 0.4230769230769231, 'outputs.gleu.gleu_result': 'fail', 'outputs.gleu.gleu_threshold': 0.5, 'outputs.meteor.meteor_score': 0.7454289732770746, 'outputs.meteor.meteor_result': 'pass', 'outputs.meteor.meteor_threshold': 0.5, 'outputs.rouge.rouge_precision': 0.6666666666666666, 'outputs.rouge.rouge_recall': 0.5714285714285714, 'outputs.rouge.rouge_f1_score': 0.6153846153846153, 'outputs.rouge.rouge_precision_result': 'pass', 'outputs.rouge.rouge_recall_result': 'pass', 'outputs.rouge.rouge_f1_score_result': 'pass', 'outputs.rouge.rouge_precision_threshold': 0.5, 'outputs.rouge.rouge_recall_threshold': 0.5, 'outputs.rouge.rouge_f1_score_threshold': 0.5}, {'inputs.response': 'She enjoys reading books.', 'inputs.ground_truth': 'She loves to read books.', 'outputs.bleu.bleu_score': 0.1098261401671543, 'outputs.bleu.bleu_result': 'fail', 'outputs.bleu.bleu_threshold': 0.5, 'outputs.gleu.gleu_score': 0.2222222222222222, 'outputs.gleu.gleu_result': 'fail', 'outputs.gleu.gleu_threshold': 0.5, 'outputs.meteor.meteor_score': 0.8203389830508474, 'outputs.meteor.meteor_result': 'pass', 'outputs.meteor.meteor_threshold': 0.5, 'outputs.rouge.rouge_precision': 0.5, 'outputs.rouge.rouge_recall': 0.4, 'outputs.rouge.rouge_f1_score': 0.4444444444444445, 'outputs.rouge.rouge_precision_result': 'pass', 'outputs.rouge.rouge_recall_result': 'fail', 'outputs.rouge.rouge_f1_score_result': 'fail', 'outputs.rouge.rouge_precision_threshold': 0.5, 'outputs.rouge.rouge_recall_threshold': 0.5, 'outputs.rouge.rouge_f1_score_threshold': 0.5}, {'inputs.response': 'He quickly ran to the store.', 'inputs.ground_truth': 'He ran to the store in a hurry.', 'outputs.bleu.bleu_score': 0.3419177649965185, 'outputs.bleu.bleu_result': 'fail', 'outputs.bleu.bleu_threshold': 0.5, 'outputs.gleu.gleu_score': 0.4, 'outputs.gleu.gleu_result': 'fail', 'outputs.gleu.gleu_threshold': 0.5, 'outputs.meteor.meteor_score': 0.6392045454545455, 'outputs.meteor.meteor_result': 'pass', 'outputs.meteor.meteor_threshold': 0.5, 'outputs.rouge.rouge_precision': 0.8333333333333334, 'outputs.rouge.rouge_recall': 0.625, 'outputs.rouge.rouge_f1_score': 0.7142857142857143, 'outputs.rouge.rouge_precision_result': 'pass', 'outputs.rouge.rouge_recall_result': 'pass', 'outputs.rouge.rouge_f1_score_result': 'pass', 'outputs.rouge.rouge_precision_threshold': 0.5, 'outputs.rouge.rouge_recall_threshold': 0.5, 'outputs.rouge.rouge_f1_score_threshold': 0.5}], 'metrics': {'bleu.bleu_score': 0.27619794053763824, 'bleu.bleu_threshold': 0.5, 'gleu.gleu_score': 0.3484330484330484, 'gleu.gleu_threshold': 0.5, 'meteor.meteor_score': 0.7349908339274891, 'meteor.meteor_threshold': 0.5, 'rouge.rouge_precision': 0.6666666666666666, 'rouge.rouge_recall': 0.5321428571428571, 'rouge.rouge_f1_score': 0.5913715913715913, 'rouge.rouge_precision_threshold': 0.5, 'rouge.rouge_recall_threshold': 0.5, 'rouge.rouge_f1_score_threshold': 0.5, 'bleu.binary_aggregate': 0.0, 'gleu.binary_aggregate': 0.0, 'meteor.binary_aggregate': 1.0, 'rouge.binary_aggregate': 0.67}, 'studio_url': None}
# {'metrics': {'bleu.binary_aggregate': 0.0,
#              'bleu.bleu_score': 0.27619794053763824,
#              'bleu.bleu_threshold': 0.5,
#              'gleu.binary_aggregate': 0.0,
#              'gleu.gleu_score': 0.3484330484330484,
#              'gleu.gleu_threshold': 0.5,
#              'meteor.binary_aggregate': 1.0,
#              'meteor.meteor_score': 0.7349908339274891,
#              'meteor.meteor_threshold': 0.5,
#              'rouge.binary_aggregate': 0.67,
#              'rouge.rouge_f1_score': 0.5913715913715913,
#              'rouge.rouge_f1_score_threshold': 0.5,
#              'rouge.rouge_precision': 0.6666666666666666,
#              'rouge.rouge_precision_threshold': 0.5,
#              'rouge.rouge_recall': 0.5321428571428571,
#              'rouge.rouge_recall_threshold': 0.5},
#  'rows': [{'inputs.ground_truth': 'A cat is sitting on the mat.',
#            'inputs.response': 'The cat sits on the mat.',
#            'outputs.bleu.bleu_result': 'fail',
#            'outputs.bleu.bleu_score': 0.3768499164492419,
#            'outputs.bleu.bleu_threshold': 0.5,
#            'outputs.gleu.gleu_result': 'fail',
#            'outputs.gleu.gleu_score': 0.4230769230769231,
#            'outputs.gleu.gleu_threshold': 0.5,
#            'outputs.meteor.meteor_result': 'pass',
#            'outputs.meteor.meteor_score': 0.7454289732770746,
#            'outputs.meteor.meteor_threshold': 0.5,
#            'outputs.rouge.rouge_f1_score': 0.6153846153846153,
#            'outputs.rouge.rouge_f1_score_result': 'pass',
#            'outputs.rouge.rouge_f1_score_threshold': 0.5,
#            'outputs.rouge.rouge_precision': 0.6666666666666666,
#            'outputs.rouge.rouge_precision_result': 'pass',
#            'outputs.rouge.rouge_precision_threshold': 0.5,
#            'outputs.rouge.rouge_recall': 0.5714285714285714,
#            'outputs.rouge.rouge_recall_result': 'pass',
#            'outputs.rouge.rouge_recall_threshold': 0.5},
#           {'inputs.ground_truth': 'She loves to read books.',
#            'inputs.response': 'She enjoys reading books.',
#            'outputs.bleu.bleu_result': 'fail',
#            'outputs.bleu.bleu_score': 0.1098261401671543,
#            'outputs.bleu.bleu_threshold': 0.5,
#            'outputs.gleu.gleu_result': 'fail',
#            'outputs.gleu.gleu_score': 0.2222222222222222,
#            'outputs.gleu.gleu_threshold': 0.5,
#            'outputs.meteor.meteor_result': 'pass',
#            'outputs.meteor.meteor_score': 0.8203389830508474,
#            'outputs.meteor.meteor_threshold': 0.5,
#            'outputs.rouge.rouge_f1_score': 0.4444444444444445,
#            'outputs.rouge.rouge_f1_score_result': 'fail',
#            'outputs.rouge.rouge_f1_score_threshold': 0.5,
#            'outputs.rouge.rouge_precision': 0.5,
#            'outputs.rouge.rouge_precision_result': 'pass',
#            'outputs.rouge.rouge_precision_threshold': 0.5,
#            'outputs.rouge.rouge_recall': 0.4,
#            'outputs.rouge.rouge_recall_result': 'fail',
#            'outputs.rouge.rouge_recall_threshold': 0.5},
#           {'inputs.ground_truth': 'He ran to the store in a hurry.',
#            'inputs.response': 'He quickly ran to the store.',
#            'outputs.bleu.bleu_result': 'fail',
#            'outputs.bleu.bleu_score': 0.3419177649965185,
#            'outputs.bleu.bleu_threshold': 0.5,
#            'outputs.gleu.gleu_result': 'fail',
#            'outputs.gleu.gleu_score': 0.4,
#            'outputs.gleu.gleu_threshold': 0.5,
#            'outputs.meteor.meteor_result': 'pass',
#            'outputs.meteor.meteor_score': 0.6392045454545455,
#            'outputs.meteor.meteor_threshold': 0.5,
#            'outputs.rouge.rouge_f1_score': 0.7142857142857143,
#            'outputs.rouge.rouge_f1_score_result': 'pass',
#            'outputs.rouge.rouge_f1_score_threshold': 0.5,
#            'outputs.rouge.rouge_precision': 0.8333333333333334,
#            'outputs.rouge.rouge_precision_result': 'pass',
#            'outputs.rouge.rouge_precision_threshold': 0.5,
#            'outputs.rouge.rouge_recall': 0.625,
#            'outputs.rouge.rouge_recall_result': 'pass',
#            'outputs.rouge.rouge_recall_threshold': 0.5}],
#  'studio_url': None}
